# %% [markdown]
# <img style="float: center; width: 100%" src="https://raw.githubusercontent.com/andrejkk/TalksImgs/master/FrontSlideUpperBan.png">
# <p style="margin-bottom:2cm;"></p>
#
#
# # Naslov projektne naloge
#
# ### Podnaslov, Äe je potreben, in po moÅ¾nosti slika
#
# Ime Priimek:
#
# Predmet: Uporabniku prilagojena komunikacija
#
# Datum:
#
#
# <p style="margin-bottom:2cm;"></p>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# ## Kazalo
#
#
# [Povzetek](#povzetek)
#
# 1. [Uvod](#uvod)
#     1. [Opredelitev podroÄja](#opredelitev-podrocja)
#     2. [Predstavitev problema](#predstavitev-problema)
# 2. [TeoretiÄno ozadje in trenutno stajne](#teoreticno-ozadje)
#     1. [TeoretiÄni vidiki problema](#teoretiÄni-vidiki-problema)
#     2. [Algoritmi](#algoritmi)
#     3. [Merjenje uspeÅ¡nosti](#merjenje-uspesnosti-resitve)
# 3. [Eksperimentalni del](#eksperimentalni-del)
#     1. [Podatki](#podatki)
#     2. [Eksperimentalni rezultati 1](#eksperimentalni-rezultati-1)
#     3. [Eksperimentalni rezultati 2](#eksperimentalni-rezultati-2)
# 4. [ZakljuÄek in razprava](#zakljucek-in-razprava)
# 5. [DoseÅ¾eni uÄni izidi](#dosezeni-ucni-izidi)
# 6. [Literatura in viri](#literatura-in-viri)
#
#
#
# <p style="margin-bottom:2cm;"></p>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# ## Povzetek <a class="anchor" id="povzetek"></a>
#
# V povzetku povzamemo bistvo projekta v smislu izhodiÅ¡Ä in rezultatov.
# </br>
#
# 1. IzhodiÅ¡Äa: </br>
#     1. Opredelitev Äasovnega pritiska: opisuje se kot izkuÅ¡nja omejenega Äasovnega okvira za dokonÄanje nalog, kar lahko vodi do poveÄanega stresa in spremenjenega vedenja.
#     2. Raziskovalno vpraÅ¡anje: Glavno vpraÅ¡anje, ki vodi Å¡tudijo, je, kako Äasovni pritisk vpliva na ÄloveÅ¡ko vedenje, tako fizioloÅ¡ko kot vedenjsko.</br>
# 2. Rezultati:</br>
#     1. Identifikacija indikatorjev: Cilj Å¡tudije je identificirati specifiÄne fizioloÅ¡ke (npr. srÄni utrip, krvni tlak) in vedenjske (npr. tveganje, hitrost dokonÄanja naloge) indikatorje Äasovnega pritiska.
#     2. Kvantifikacija razmerij: Prizadeva si kvantificirati razmerje med Äasovnim pritiskom ter temi fizioloÅ¡kimi in vedenjskimi indikatorji.
# 3. Prihodnje raziskovalne smeri: Å tudija nakazuje, da bi napredne raziskave lahko raziskale dolgoroÄne uÄinke kroniÄnega Äasovnega pritiska in njegov vpliv na duÅ¡evno in fiziÄno zdravje.
#
# <p style="margin-bottom:2cm;"></p>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# ## 1. Uvod <a class="anchor" id="uvod"></a>
#
# V uvodu bralca opremimo z vsemi izhodiÅ¡Äi, ki jih potrebuje za razumevanje problema in reÅ¡itve. Å irÅ¡a opredelitev podroÄja je berljiva za laike, ob koncu uvoda pa natanÄno specificiramo problem v smislu mnoÅ¾ic ali v smislu definiranega problema strojnega uÄenja.
#
#
# <p style="margin-bottom:2cm;"></p>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# ### 1.1. Opredelitev podroÄja <a class="anchor" id="opredelitev-podrocja"></a>
#
# Å irÅ¡a opredelitev podroÄja projekta kot je npr. merjenje uporabnikov s potrebnimi opredelitvami za umestitev. Ta opredelitev je brez tehniÄnih podrobnosti in se ukvarja z aplikativno umestitvijo.
#
#
# <p style="margin-bottom:2cm;"></p>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# ### 1.2. Predstavitev problema <a class="anchor" id="predstavitev-problema"></a>
#
# Aplikativna postavitev problema na podroÄju.
# Sledi natanÄna opredelitev problema v tehniÄnem jeziku z mnoÅ¾icami ali strojnim uÄenjem, npr. nadzorovana klasifikacija z opredletivijo razredov ipd.
#
#
# <p style="margin-bottom:2cm;"></p>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# ## 2. TeoretiÄno ozadje in trenutno stanje <a class="anchor" id="teoreticno-ozadje-in-trenutno-stanje"></a>
#
#
# TeoretiÄno ozadje predstavlja potrebne koncepte kot je npr. afektivni prostor VAD in model Äustev.
#
# Opredelimo tudi trenutno stanje, to je glavne obstojeÄe reÅ¡itve, ki jih najdete v literaturi.
#
#
# <p style="margin-bottom:2cm;"></p>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# ### 2.1. TeoretiÄni vidiki problema <a class="anchor" id="teoretiÄni-vidiki-problema"></a>
#
#
# Predstavimo relevantne vidike problema, vkljuÄno z dovolj natanÄno opredelitvijo nosilnih pojmov. Gre za relevantno teorijo, ki jo navadno povzamete po literaturi (raziskovalnih Älankih itd).
#
#
#
# <p style="margin-bottom:2cm;"></p>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# ### 2.2. Algoritmi <a class="anchor" id="algoritmi"></a>
#
#
# OpiÅ¡emo algoritme na podroÄju vkljuÄno z uporabljenimi algoritmi. Opis algoritma mora vsebovati pravo ime, referenco na podroben opis, ter grob opis postopka. Navedete tudi knjiÅ¾nico (Python ali drugo), ki ste jo pri izvajanju algoritma uporabili.
#
# ÄŒe je veÄ konkurenÄnih algoritmov za reÅ¡itev danega problema, jih opiÅ¡ete veÄ. NavjeÄ pozornosti posvetite uporabljenim algoritmom.
#
#
#
# <p style="margin-bottom:2cm;"></p>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# ### 2.3. Merjenje uspeÅ¡nosti reÅ¡itve <a class="anchor" id="merjenje-uspesnosti-resitve"></a>
#
# OpiÅ¡emo naÄin merjenja uspeÅ¡nosti reÅ¡itve kot je npr. F1 mera, povrÅ¡ina pod ROC krivuljo ipd. VkljuÄimo opis metrike in definicijsko enaÄbo metrike.
#
#
# </br>
# <p style="margin-bottom:2cm;"></p>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# ## 3. Eksperimentalni del <a class="anchor" id="eksperimentalni-del"></a>
#
#
# Opis eksperimenta na naÄin, ki bi bralcu omogoÄal njegovo ponovitev - Äe bi razpolagal s podatki in ustreznim znanjem.
#
# Eksperimentalne rezultate navajamo po smiselnih skupinah, spodaj je navedeno za primer dveh skupin.
#
# Projekt opremite z navodili za zagon programske kode vkljuÄno z dostopom do testnih podatkov (ali pripnete ali podate povezavo). Ta navodila vkljuÄujejo tudi potrebne knjiÅ¾nice in druge nastavitve, potrebne za zagon kode.
#
#
#
#
# <p style="margin-bottom:2cm;"></p>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# ### 3.1. Podatki <a class="anchor" id="podatki"></a>
#
#
# Predstavimo testne podatke (izvor, velikost, podatkovna polja, lastnosti). Za javno dostopne podatke navedemo povezavo do skladiÅ¡Äa.
# DobrodoÅ¡la je slika primerov podatkov Äe gre za Äasovno odvisne podatke ipd.
#
#
#
# <p style="margin-bottom:2cm;"></p>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# ### 3.2. Eksperimentalni rezultati 1 <a class="anchor" id="eksperimentalni-rezultati-1"></a>
#
#
# Predstavitev eksperimentalnih rezultatov, tabele, grafi, kratka interpretacija.
#
#
#
# <p style="margin-bottom:2cm;"></p>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# ### 3.3. Eksperimentalni rezultati 2 <a class="anchor" id="eksperimentalni-rezultati-2"></a>
#
#
# Predstavitev eksperimentalnih rezultatov, tabele, grafi, kratka interpretacija.
#
#
#
# <p style="margin-bottom:2cm;"></p>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# ## 4. ZakljuÄek in razprava <a class="anchor" id="zakljucek-in-razprava"></a>
#
#
# ZakljuÄki - kaj lahko sklepamo neposredno iz eksperimentalnih rezultatov v strogem smislu, to je kar sledi neposredno iz dobljenih rezultatov.
#
#
# Glavni rezultati - povzetek v smislu glavne ugotovitve. Kaj sledi iz doseÅ¾enih rezultatov.
#
#
# OpaÅ¾anja in razprava - tu so na mestu Å¡irÅ¡a opazanja, lahko tudi sama mnenja glede doseÅ¾enih rezultatov.
#
#
#
# <p style="margin-bottom:2cm;"></p>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# ## 5. DoseÅ¾eni uÄni izidi <a class="anchor" id="dosezeni-ucni-izidi"></a>
#
#
# Kaj ste se pri izdelavi projekta nauÄili. Na kratko v poljudnem jeziku, med drugim:
# - Razumevanje teoretiÄnih konceptov.
# - Spoznavanje algoritmov.
# - Pridobljene izkuÅ¡nje s podatki.
#
#
#
# <p style="margin-bottom:2cm;"></p>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">

# %% [markdown]
# ## 6. Literatura in viri  <a class="anchor" id="literatura-in-viri"></a>
#
# Seznam literature
#
# Explores the VAD (Valence, Arousal, Dominance) model and its application in understanding human emotions.
# Wickens, C. D. (2008). "Multiple Resources and Mental Workload." Human Factors: The Journal of the Human Factors and Ergonomics Society.
#
#
#
# <p style="margin-bottom:2cm;"></p>
# <img src="https://raw.githubusercontent.com/andrejkk/ORvTK_SlidesImgs/master/footer_full.jpg">
